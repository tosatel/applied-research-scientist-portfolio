# %% [markdown]
# # Trust-Aware RAG Security Lab
# Reproducible analysis of retrieval poisoning and trust-aware defenses.

# %%
from pathlib import Path
import sys,pandas as pd
PROJECT=Path.cwd(); PROJECT=PROJECT.parent if PROJECT.name=='notebooks' else PROJECT
sys.path.insert(0,str(PROJECT/'src'))
from experiment import read,run,summary
docs=read(PROJECT/'data/documents.csv'); queries=read(PROJECT/'data/queries.csv')
results=run(docs,queries)
pd.DataFrame(summary(results))
